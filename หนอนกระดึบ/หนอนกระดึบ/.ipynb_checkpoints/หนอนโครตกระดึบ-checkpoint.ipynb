# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('plotData.csv')

# %%
df.head()
# Out:
#             Unnamed: 0     sensor1     sensor2     sensor3     sensor4  \
# 0  2019-11-05 00:00:00   98.894310  126.933682   94.689281  107.328125
# 1  2019-11-05 00:01:00  101.238907  120.542236  109.287640   99.872089
# 2  2019-11-05 00:02:00   94.386368  102.647774   87.449806   86.383228
# 3  2019-11-05 00:03:00   80.918354   96.385818   91.669785   91.212303
# 4  2019-11-05 00:04:00  103.639690   84.957104   92.271114  103.514515
#
#      sensor5    sensor6    sensor7     sensor8    sensor9  ...    sensor24  \
# 0        NaN  84.786873  96.313023   99.578835  85.912354  ...  127.139149
# 1  90.789818  92.261373  85.954595  110.415169  90.073643  ...   72.354792
# 2        NaN  83.691719  66.709484  106.517502  90.534679  ...  131.842483
# 3  80.765694  86.695862  87.335812   98.658936  89.150604  ...  101.993149
# 4        NaN  94.097865  88.365051   98.633747  80.178834  ...  105.857938
#
#      sensor25    sensor26    sensor27    sensor28    sensor29    sensor30  \
# 0  104.525917   79.994673   99.389356  102.486931   86.857306  101.691940
# 1   94.022984   90.957184   95.983678  121.585953  106.620522  103.586863
# 2  109.314817  115.085792  119.059733  103.288712   95.465752  115.349864
# 3  118.613277   93.808525  105.169118  120.076004   93.755520  106.498405
# 4  102.168833  102.204914  116.628614  122.117165  115.196887  105.160589
#
#      sensor31   sensor32    sensor33
# 0   99.515971  88.636513   85.666470
# 1   84.012081  51.783093  101.985680
# 2  118.602493  89.851135   93.073357
# 3   95.106308  82.826355   88.289288
# 4   94.798050  82.270962   96.520031
#
# [5 rows x 34 columns]

# %%
km = [0,1300,3000,5100,6955,9310,11320,13220,15590,17825,19920,21335,23255,25375,28020,30620]

# %%
len(km)
# Out:
# 16

# %%
# Create an empty list 
Row_list =[] 
  
# Iterate over each row 
for index, rows in df.iterrows(): 
    # Create list for the current row 
    my_list =[rows['sensor{}'.format(i)] for i in range(1,34) if i%2==0] 
      
    # append the list to the final list 
    Row_list.append(my_list)

# %%
plt.scatter(km, Row_list[0])

# %%
p4 = np.poly1d(np.polyfit(km, Row_list[0], 10))

# %%
xp = np.linspace(0,30700,1000)
plt.scatter(km, Row_list[0])
plt.plot(xp, p4(xp), c='r')

# %%
p4 = np.poly1d(np.polyfit(km, Row_list[1], 10))
xp = np.linspace(0,30700,1000)
plt.scatter(km, Row_list[1])
plt.plot(xp, p4(xp), c='r')

# %%
def interpolation(km, Rowlist_ind):
    p4 = np.poly1d(np.polyfit(km, Row_list[Rowlist_ind], 10))
    row = [p4(i*100) for i in range(307)]
    return row

# %%
times = pd.date_range("2019-11-05 00:00:00", "2019-11-05 23:59:00", freq="1min")
df_None = pd.DataFrame(columns=[i*100 for i in range(307)], index=times)

# %%
dist = km
for i, t in enumerate(times):
    row_int = interpolation(dist, i)
    df_None.loc[t] = row_int

# %%
df_None
# Out:
#                        0        100      200      300      400      500    \
# 2019-11-05 00:00:00  127.431  125.985  124.426  122.776  121.056  119.286
# 2019-11-05 00:01:00  121.029  117.887  115.019  112.411  110.047  107.913
# 2019-11-05 00:02:00  102.985  101.398   99.754  98.0874  96.4269  94.7976
# 2019-11-05 00:03:00  96.1272  97.8711  99.0292  99.6858  99.9175  99.7939
# 2019-11-05 00:04:00  84.9535  88.7018  91.9017  94.6047  96.8586  98.7083
# ...                      ...      ...      ...      ...      ...      ...
# 2019-11-05 23:55:00  105.403  104.196  103.121  102.161  101.299  100.521
# 2019-11-05 23:56:00  99.3231  101.349  102.929  104.119   104.97   105.53
# 2019-11-05 23:57:00  102.095  95.9529  90.7585  86.4022  82.7837   79.812
# 2019-11-05 23:58:00  110.149   112.88  115.062  116.756  118.016  118.893
# 2019-11-05 23:59:00      NaN      NaN      NaN      NaN      NaN      NaN
#
#                        600      700      800      900    ...    29700  \
# 2019-11-05 00:00:00  117.485  115.666  113.847   112.04  ...  91.2389
# 2019-11-05 00:01:00  105.994  104.278  102.752  101.403  ...  33.7376
# 2019-11-05 00:02:00  93.2209   91.715  90.2951  88.9736  ...  159.373
# 2019-11-05 00:03:00  99.3782   98.727  97.8914  96.9168  ...  95.1446
# 2019-11-05 00:04:00  100.196  101.359  102.235  102.857  ...  69.0175
# ...                      ...      ...      ...      ...  ...      ...
# 2019-11-05 23:55:00  99.8136  99.1649  98.5649  98.0045  ...  146.434
# 2019-11-05 23:56:00   105.84   105.94  105.864  105.644  ...  97.1868
# 2019-11-05 23:57:00  77.4048  75.4879  73.9945  72.8649  ...  -28.901
# 2019-11-05 23:58:00  119.435  119.683  119.678  119.455  ...  100.482
# 2019-11-05 23:59:00      NaN      NaN      NaN      NaN  ...      NaN
#
#                        29800    29900    30000    30100    30200    30300  \
# 2019-11-05 00:00:00  90.4378  89.7011  89.0499  88.5076     88.1  87.8553
# 2019-11-05 00:01:00  31.6108  30.1816  29.5604  29.8663  31.2278   33.783
# 2019-11-05 00:02:00  158.028  155.591  151.906  146.806  140.108  131.616
# 2019-11-05 00:03:00  94.3407  93.4656  92.4991  91.4182  90.1968   88.805
# 2019-11-05 00:04:00   68.219  67.8164  67.8656  68.4269  69.5645  71.3476
# ...                      ...      ...      ...      ...      ...      ...
# 2019-11-05 23:55:00   144.19  141.234  137.503  132.924  127.426   120.93
# 2019-11-05 23:56:00  95.5055  93.6025  91.4549  89.0374  86.3224    83.28
# 2019-11-05 23:57:00 -29.5687 -27.9922 -23.8276 -16.7009  -6.2071  8.09224
# 2019-11-05 23:58:00  101.305  102.394  103.775  105.475  107.524  109.952
# 2019-11-05 23:59:00      NaN      NaN      NaN      NaN      NaN      NaN
#
#                        30400    30500    30600
# 2019-11-05 00:00:00  87.8048  87.9821  88.4244
# 2019-11-05 00:01:00  37.6807  43.0803  50.1526
# 2019-11-05 00:02:00  121.117  108.383  93.1671
# 2019-11-05 00:03:00  87.2093  85.3721  83.2514
# 2019-11-05 00:04:00  73.8502   77.151  81.3343
# ...                      ...      ...      ...
# 2019-11-05 23:55:00  113.355  104.615  94.6194
# 2019-11-05 23:56:00  79.8775  76.0794  71.8471
# 2019-11-05 23:57:00  26.6707  50.0388  78.7466
# 2019-11-05 23:58:00   112.79  116.072  119.832
# 2019-11-05 23:59:00      NaN      NaN      NaN
#
# [1440 rows x 307 columns]

# %%
Z = df_None.to_numpy().transpose()

# %%
import matplotlib.pyplot as plt

# %%
y = np.arange(307)
x = np.arange(1440)
X, Y = np.meshgrid(x,y)

# %%
fig = plt.figure()
ax1 = plt.contourf(X, Y, Z)
plt.colorbar(ax1)
plt.ylabel('sensor index')
plt.xlabel('time(minute)')
plt.savefig('growth24.png')
plt.show()
