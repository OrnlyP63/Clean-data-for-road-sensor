# %%
import sqlite3
import pandas as pd
conn = sqlite3.connect('test.db')

# %%
# df = pd.read_csv('2019-11-(4-8).csv',parse_dates=['date'])
# df['date'] = df["date"].dt.strftime("%Y-%m-%d %H:%M")
# df.to_csv('DayFormat.csv',index=False)
# df.head()

# %%
#times.strftime("%Y-%m-%d %H:%M")

# %%
df = pd.read_sql_query(f"SELECT date,round(avg(density),2) AS Density FROM DayFormat WHERE agg_tag = 2 AND date like '2019-11-04%' GROUP BY date ORDER BY date", conn)

# %%
df = pd.read_csv('Density_day4.csv')

# %%
df[['Density1', 'Density2']]
# Out:
#       Density1  Density2
# 0         1.74      2.52
# 1         0.90      3.30
# 2         1.98      2.23
# 3         1.19      1.07
# 4         1.54      2.86
# ...        ...       ...
# 1435      0.78      2.80
# 1436      0.85      1.63
# 1437      1.19      0.78
# 1438      1.50      1.10
# 1439      2.11      1.43
#
# [1440 rows x 2 columns]

# %%
df.head()
# Out:
#                date  Density
# 0  2019-11-04 00:00     2.52
# 1  2019-11-04 00:01     3.30
# 2  2019-11-04 00:02     2.23
# 3  2019-11-04 00:03     1.07
# 4  2019-11-04 00:04     2.86

# %%
for d in range(4,9):
    times = pd.date_range(f"2019-11-0{d} 00:00", f"2019-11-0{d} 23:59", freq="1min")
    times = times.strftime("%Y-%m-%d %H:%M")
    DF = pd.DataFrame(times,columns=['date'])
    D_list = [DF]
    for i in range(1,34):
        df = pd.read_sql_query(f"SELECT date,round(avg(density),2) AS Density{i} FROM DayFormat WHERE agg_tag = {i} AND date like '2019-11-0{d}%' GROUP BY date ORDER BY date", conn)
        DF = pd.merge(DF, df, on='date', how='left')
    DF.to_csv(f'Density_day{d}.csv',index=False)

# %%
DF
# Out:
#                   date  Density1  Density2  Density3  Density4  Density5  \
# 0     2019-11-04 00:00      1.74      2.52      1.42      1.62       NaN
# 1     2019-11-04 00:01      0.90      3.30      1.41      0.97      0.51
# 2     2019-11-04 00:02      1.98      2.23      1.38      2.45      1.80
# 3     2019-11-04 00:03      1.19      1.07      1.01      0.55      0.60
# 4     2019-11-04 00:04      1.54      2.86      1.55      2.32      0.63
# ...                ...       ...       ...       ...       ...       ...
# 1435  2019-11-04 23:55      0.78      2.80      0.59      2.55       NaN
# 1436  2019-11-04 23:56      0.85      1.63      0.60      0.90      1.30
# 1437  2019-11-04 23:57      1.19      0.78      0.84      0.88       NaN
# 1438  2019-11-04 23:58      1.50      1.10      0.97      2.73      1.17
# 1439  2019-11-04 23:59      2.11      1.43      1.33      0.51      0.92
#
#       Density6  Density7  Density8  Density9  ...  Density24  Density25  \
# ...

# %%
DF.to_csv('Density.csv',index=False)

# %%
times = pd.date_range("2019-11-04 00:00", "2019-11-04 23:59", freq="1min")

# %%
df
# Out:
#                   date  Density1
# 0     2019-11-04 00:00      1.74
# 1     2019-11-04 00:01      0.90
# 2     2019-11-04 00:02      1.98
# 3     2019-11-04 00:03      1.19
# 4     2019-11-04 00:04      1.54
# ...                ...       ...
# 1387  2019-11-04 23:55      0.78
# 1388  2019-11-04 23:56      0.85
# 1389  2019-11-04 23:57      1.19
# 1390  2019-11-04 23:58      1.50
# 1391  2019-11-04 23:59      2.11
#
# [1392 rows x 2 columns]

# %%
DF
# Out:
#                   date
# 0     2019-11-04 00:00
# 1     2019-11-04 00:01
# 2     2019-11-04 00:02
# 3     2019-11-04 00:03
# 4     2019-11-04 00:04
# ...                ...
# 1435  2019-11-04 23:55
# 1436  2019-11-04 23:56
# 1437  2019-11-04 23:57
# 1438  2019-11-04 23:58
# 1439  2019-11-04 23:59
#
# [1440 rows x 1 columns]

# %%
dummy_data1 = {
        'id': ['1', '2', '3', '4', '5'],
        'Feature1': ['A', 'C', 'E', 'G', 'I'],
        'Feature2': ['B', 'D', 'F', 'H', 'J']}
df1 = pd.DataFrame(dummy_data1, columns = ['id', 'Feature1', 'Feature2'])

df1
# Out:
#   id Feature1 Feature2
# 0  1        A        B
# 1  2        C        D
# 2  3        E        F
# 3  4        G        H
# 4  5        I        J

# %%
dummy_data2 = {
        'id': ['1', '2', '6', '7', '8'],
        'Feature1': ['K', 'M', 'O', 'Q', 'S'],
        'Feature2': ['L', 'N', 'P', 'R', 'T']}
df1 = pd.DataFrame(dummy_data1, columns = ['id', 'Feature1', 'Feature2'])

df1
# Out:
#   id Feature1 Feature2
# 0  1        A        B
# 1  2        C        D
# 2  3        E        F
# 3  4        G        H
# 4  5        I        J

# %%
dummy_data3 = {
        'id': ['1', '2', '3', '4', '5', '7', '8', '9', '10', '11'],
        'Feature3': [12, 13, 14, 15, 16, 17, 15, 12, 13, 23]}
df3 = pd.DataFrame(dummy_data3, columns = ['id', 'Feature3'])

df3
# Out:
#    id  Feature3
# 0   1        12
# 1   2        13
# 2   3        14
# 3   4        15
# 4   5        16
# 5   7        17
# 6   8        15
# 7   9        12
# 8  10        13
# 9  11        23

# %%
df_row = pd.concat([df1, df2])

df_row
# Out:
#   id Feature1 Feature2
# 0  1        A        B
# 1  2        C        D
# 2  3        E        F
# 3  4        G        H
# 4  5        I        J
# 0  1        K        L
# 1  2        M        N
# 2  6        O        P
# 3  7        Q        R
# 4  8        S        T

# %%
dF = pd.concat([DF,df])

# %%
dF
# Out:
#                   date  Density33
# 0     2019-11-04 00:00        NaN
# 1     2019-11-04 00:01        NaN
# 2     2019-11-04 00:02        NaN
# 3     2019-11-04 00:03        NaN
# 4     2019-11-04 00:04        NaN
# ...                ...        ...
# 1422  2019-11-04 23:55       2.19
# 1423  2019-11-04 23:56       1.85
# 1424  2019-11-04 23:57       4.55
# 1425  2019-11-04 23:58       2.28
# 1426  2019-11-04 23:59       4.29
#
# [2867 rows x 2 columns]
